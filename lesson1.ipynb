# %% [markdown]
# <a href="https://colab.research.google.com/github/khanbaba-ahamaliiev/ITStep-AI/blob/superwised_learning/lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "john"
age = 30

print(name, age)
# Out:
# john 30

# %%
print(age)
# Out:
# 30
